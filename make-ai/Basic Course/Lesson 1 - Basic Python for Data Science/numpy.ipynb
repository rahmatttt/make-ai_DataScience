# %% [markdown]
# # Numpy

# %% [markdown]
# numpy(numeric python) adalah sebuah library yang biasa digunakan untuk data science dan machine learning. Numpy digunakan karena kemudahannya dalam melakukan operasi matematika khusunya matriks
#
# untuk menggunakannya kita harus menambahkan code:
#     - import numpy

# %%
import numpy as np

# %% [markdown]
# numpy memiliki bentuk yang mirip dengan list, namun ada beberapa perbedaan:
#     - numpy hanya terdiri dari 1 tipe value yang sama
#     - jika kita print tipe numpy maka akan seperti list namun tanpa tanda koma

# %%
a = np.array([1,2,3])
b = [1,2,3]

# %%
print(a)
# Out:
# [1 2 3]

# %%
print(b)
# Out:
# [1, 2, 3]

# %%
c = [10, 8.5, "hello"]
d = np.array([10, 8.5, "hello"])

# %%
c
# Out:
# [10, 8.5, 'hello']

# %%
d
# Out:
# array(['10', '8.5', 'hello'], dtype='<U32')

# %% [markdown]
# urutan prioritas tipe dalam numpy array:
#     1. string
#     2. float
#     3. integer

# %%
e = np.array([10, 11, 2.5])

# %%
e
# Out:
# array([10. , 11. ,  2.5])

# %%
a = np.array([3,5,7,8])
a
# Out:
# array([3, 5, 7, 8])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
b = np.array([[2,5],[3,4]])
b
# Out:
# array([[2, 5],
#        [3, 4]])

# %%
b.shape
# Out:
# (2, 2)

# %%
b = np.array([[2,5,6],[3,4,10]])
b
# Out:
# array([[ 2,  5,  6],
#        [ 3,  4, 10]])

# %%
b.shape
# Out:
# (2, 3)

# %%
b[0]
# Out:
# array([2, 5, 6])

# %%
b[0][1]
# Out:
# 5

# %%
b[1][2]
# Out:
# 10

# %%
bb = np.array([[2,5],[3,4,7]])
bb
# Out:
# array([list([2, 5]), list([3, 4, 7])], dtype=object)

# %%
bb[0]
# Out:
# [2, 5]

# %%
bb[1][2]
# Out:
# 7

# %%
a = np.array([3,5,6])
b = np.array([8,1,2])

# %%
a+b
# Out:
# array([11,  6,  8])

# %%
a+(2*b)
# Out:
# array([19,  7, 10])

# %%
a-b
# Out:
# array([-5,  4,  4])

# %%
2*b
# Out:
# array([16,  2,  4])

# %%
a*b
# Out:
# array([24,  5, 12])

# %%
c = np.array([3,5,6])
d = np.array([8,1,])
c+d
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5bd69ba76b43> in <module>
#       1 c = np.array([3,5,6])
#       2 d = np.array([8,1,])
# ----> 3 c+d
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %%
len(c)
# Out:
# 3

# %%
a = np.array([1,2,3,6,4,0,10,7,8,9])

# %%
a
# Out:
# array([ 1,  2,  3,  6,  4,  0, 10,  7,  8,  9])

# %%
len(a)
# Out:
# 10

# %%
a.min()
# Out:
# 0

# %%
a.max()
# Out:
# 10

# %%
a.mean()
# Out:
# 5.0

# %% [markdown]
# more advance

# %%
a = np.array([[1,2],[3,4]])
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.shape
# Out:
# (2, 2)

# %%
b = np.array([[2,5],[9,1]])
b
# Out:
# array([[2, 5],
#        [9, 1]])

# %%
a.dot(b) #perkalian matriks
# Out:
# array([[20,  7],
#        [42, 19]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
c = np.array([5,6,7,8,9,10])
c
# Out:
# array([ 5,  6,  7,  8,  9, 10])

# %%
a.dot(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-2f0e736d490a> in <module>
# ----> 1 a.dot(c)
#
# ValueError: shapes (2,2) and (6,) not aligned: 2 (dim 1) != 6 (dim 0)

# %%
#ingat aturan perkalian matriks

# %%
#c harus diubah ordonya dengan reshape

# %%
c = c.reshape(2,3) #len(c) = 6, maka ordo barunya 2x3 (2x3 = 6)
c
# Out:
# array([[ 5,  6,  7],
#        [ 8,  9, 10]])

# %%
a.dot(c)
# Out:
# array([[21, 24, 27],
#        [47, 54, 61]])

# %%
a.shape
# Out:
# (2, 2)

# %%
c.shape
# Out:
# (2, 3)

# %%
c.dot(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-2263961f831a> in <module>
# ----> 1 c.dot(a)
#
# ValueError: shapes (2,3) and (2,2) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
#c bisa ditranspose

# %%
c = c.transpose()
c
# Out:
# array([[ 5,  8],
#        [ 6,  9],
#        [ 7, 10]])

# %%
c.dot(a)
# Out:
# array([[29, 42],
#        [33, 48],
#        [37, 54]])

# %%
c.shape
# Out:
# (3, 2)
