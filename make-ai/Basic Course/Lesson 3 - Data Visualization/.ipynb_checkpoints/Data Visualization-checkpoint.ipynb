# %% [markdown]
# ![Logo%20MatLearn%20Transparent.png](attachment:Logo%20MatLearn%20Transparent.png)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# - Kenapa visualisasi data dibutuhkan?
#     Visualisasi data adalah konversi data menjadi bentuk visual agar mudah dipahami. Visual yang biasa digunakan adalah dalam bentuk grafik
#
# - Tipe chart (bar chart, pie chart, dll)
#
# - statistical chart

# %% [markdown]
# ## Matlpotlib dan Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('athlete_events.csv')
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %% [markdown]
# data di atas adalah data atlet pada olimpiade. Kita akan membuat visualisasi data untuk data olimpiade Brazil tahun 2016. Kita akan melihat berdasarkan perolehan medali, jika kita lihat pada data di atas pada kolom Medal banyak ditemukan NaN yang artinya value nya tidak ada, maka dari itu kita harus membuatnya memiliki value

# %% [markdown]
# ## Mengatasi missing value

# %% [markdown]
# Kita cek dulu tahun berlangsungnya olimpiade

# %%
df['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1988, 1994, 1932, 2002, 1952, 1980, 2000,
#        1996, 1912, 1924, 2014, 1948, 1998, 2006, 2008, 2016, 2004, 1960,
#        1964, 1984, 1968, 1972, 1936, 1956, 1928, 1976, 2010, 1906, 1904,
#        1908, 1896], dtype=int64)

# %% [markdown]
# Setelah itu kita cek ukuran dari data

# %%
df.shape
# Out:
# (271116, 15)

# %% [markdown]
# kita ambil data tahun 2016

# %%
df = df[df['Year'] == 2016]
df
# Out:
#             ID                                     Name Sex   Age  Height  \
# 80          22                            Andreea Aanei   F  22.0   170.0
# 139         51                        Nstor Abad Sanjun   M  23.0   167.0
# 140         51                        Nstor Abad Sanjun   M  23.0   167.0
# 141         51                        Nstor Abad Sanjun   M  23.0   167.0
# 142         51                        Nstor Abad Sanjun   M  23.0   167.0
# 143         51                        Nstor Abad Sanjun   M  23.0   167.0
# 144         51                        Nstor Abad Sanjun   M  23.0   167.0
# 148         55                      Antonio Abadia Beci   M  26.0   170.0
# 158         62                        Giovanni Abagnale   M  21.0   198.0
# 161         65                        Patimat Abakarova   F  21.0   165.0
# 175         73                                Luc Abalo   M  31.0   182.0
# 217        105                             Ilyas Abbadi   M  23.0   175.0
# ...

# %% [markdown]
# cek ukurannya lagi

# %%
df.shape
# Out:
# (13688, 15)

# %% [markdown]
# ada 13688 data dari tahun 2016

# %% [markdown]
# sekarang isi value yang kosong dengan 'none' dengan fungsi fillna(). fungsi fillna() adalah fungsi yang berfungsi untuk mengisi field yang kosong

# %%
df = df.fillna({'Medal' : 'none'})

# %%
df.head()
# Out:
#      ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80   22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 139  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 140  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 141  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 142  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
#
#            Games  Year  Season            City          Sport  \
# 80   2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 139  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 140  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 141  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 142  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight  none
# 139   Gymnastics Men's Individual All-Around  none
# ...

# %% [markdown]
# data NaN sudah berubah jadi none

# %% [markdown]
# ## Mengubah data kategorikal menjadi numerikal

# %% [markdown]
# sekarang kita akan mencari tau berapa medali yang diperoleh tiap negara

# %%
All_go = pd.DataFrame(df.groupby(['NOC','Medal'])['Medal'].size())
All_go
# Out:
#             Medal
# NOC Medal
# AFG none        3
# ALB none        6
# ALG Silver      2
#     none       72
# AND none        4
# ANG none       26
# ANT none        9
# ARG Gold       21
#     Silver      1
#     none      210
# ARM Gold        1
#     Silver      3
#     none       30
# ARU none        7
# ASA none        4
# AUS Bronze     25
#     Gold       23
#     Silver     34
#     none      436
# AUT Bronze      2
#     none       83
# AZE Bronze     10
#     Gold        1
#     Silver      7
#     none       51
# BAH Bronze      5
#     Gold        1
#     none       32
# BAN none        7
# BAR none       13
# ...           ...
# TUR Silver      3
#     none      111
# TUV none        1
# UAE Bronze      1
#     none       11
# UGA none       23
# UKR Bronze      5
#     Gold        2
#     Silver      8
#     none      257
# URU none       17
# USA Bronze     71
#     Gold      139
#     Silver     54
#     none      455
# UZB Bronze      7
#     Gold        4
# ...

# %% [markdown]
# Data di atas bentuknya adalah multi indeks, maka dari itu kita harus mengubahnya menjadi satu indeks. Namun sebelum kita buat jadi satu indeks kita lihat bahwa ada dua kolom Medal disitu, maka dari itu kita harus mengubah salah satunya

# %%
All_go.columns = ['Total']
All_go
# Out:
#             Total
# NOC Medal
# AFG none        3
# ALB none        6
# ALG Silver      2
#     none       72
# AND none        4
# ANG none       26
# ANT none        9
# ARG Gold       21
#     Silver      1
#     none      210
# ARM Gold        1
#     Silver      3
#     none       30
# ARU none        7
# ASA none        4
# AUS Bronze     25
#     Gold       23
#     Silver     34
#     none      436
# AUT Bronze      2
#     none       83
# AZE Bronze     10
#     Gold        1
#     Silver      7
#     none       51
# BAH Bronze      5
#     Gold        1
#     none       32
# BAN none        7
# BAR none       13
# ...           ...
# TUR Silver      3
#     none      111
# TUV none        1
# UAE Bronze      1
#     none       11
# UGA none       23
# UKR Bronze      5
#     Gold        2
#     Silver      8
#     none      257
# URU none       17
# USA Bronze     71
#     Gold      139
#     Silver     54
#     none      455
# UZB Bronze      7
#     Gold        4
# ...

# %%
All_go = All_go.reset_index()
All_go.head()
# Out:
#    NOC   Medal  Total
# 0  AFG    none      3
# 1  ALB    none      6
# 2  ALG  Silver      2
# 3  ALG    none     72
# 4  AND    none      4

# %% [markdown]
# Sekarang data tersebut sudah memiliki satu index namun jika kita lihat pada index ke 2 dan 3 data tersebut adalah sama (sama-sama ALG) walaupun Medalnya berbeda

# %%
All_go['None'] = np.where(All_go['Medal'] == 'none', All_go['Total'], 0)
All_go['G'] = np.where(All_go['Medal'] == 'Gold', All_go['Total'], 0)
All_go['S'] = np.where(All_go['Medal'] == 'Silver', All_go['Total'], 0)
All_go['B'] = np.where(All_go['Medal'] == 'Bronze', All_go['Total'], 0)

# %%
All_go.head()
# Out:
#    NOC   Medal  Total  None  G  S  B
# 0  AFG    none      3     3  0  0  0
# 1  ALB    none      6     6  0  0  0
# 2  ALG  Silver      2     0  0  2  0
# 3  ALG    none     72    72  0  0  0
# 4  AND    none      4     4  0  0  0

# %%
All_go = All_go.groupby(['NOC'], as_index = False).sum()

# %%
All_go
# Out:
#      NOC  Total  None    G   S   B
# 0    AFG      3     3    0   0   0
# 1    ALB      6     6    0   0   0
# 2    ALG     74    72    0   2   0
# 3    AND      4     4    0   0   0
# 4    ANG     26    26    0   0   0
# 5    ANT      9     9    0   0   0
# 6    ARG    232   210   21   1   0
# 7    ARM     34    30    1   3   0
# 8    ARU      7     7    0   0   0
# 9    ASA      4     4    0   0   0
# 10   AUS    518   436   23  34  25
# 11   AUT     85    83    0   0   2
# 12   AZE     69    51    1   7  10
# 13   BAH     38    32    1   0   5
# 14   BAN      7     7    0   0   0
# 15   BAR     13    13    0   0   0
# 16   BDI     10     9    0   1   0
# 17   BEL    138   117    2  17   2
# 18   BEN      6     6    0   0   0
# 19   BER      8     8    0   0   0
# 20   BHU      2     2    0   0   0
# 21   BIH     11    11    0   0   0
# 22   BIZ      3     3    0   0   0
# 23   BLR    142   130    1   4   7
# 24   BOL     12    12    0   0   0
# 25   BOT     14    14    0   0   0
# ...

# %% [markdown]
# Mari kita sorting berdasarkan medalinya

# %%
All_go = All_go.sort_values(['G','S','B'], ascending=False)

# %%
All_go
# Out:
#      NOC  Total  None    G   S   B
# 198  USA    719   455  139  54  71
# 68   GBR    478   333   64  55  26
# 159  RUS    406   291   52  28  35
# 72   GER    536   377   49  43  67
# 38   CHN    499   386   46  30  37
# 26   BRA    583   533   36   8   6
# 10   AUS    518   436   23  34  25
# 6    ARG    232   210   21   1   0
# 64   FRA    512   416   20  55  21
# 97   JPN    436   372   17  13  34
# 51   DEN    143   102   15  10  16
# 171  SRB    127    73   14  27  13
# 102  KOR    263   237   13   3  10
# 62   FIJ     53    40   13   0   0
# 83   HUN    204   182   12   3   7
# 95   JAM     77    47   11  17   2
# 135  NED    329   282    9  25  13
# 59   ESP    363   318    9  19  17
# 93   ITA    399   327    8  40  24
# 47   CRO     93    69    7  15   2
# 141  NZL    232   196    6  25   5
# 99   KEN     80    67    6   6   1
# 176  SUI    152   141    6   3   2
# 48   CUB    143   132    5   2   4
# 33   CAN    405   336    4   4  61
# 157  ROU    121   105    4   2  10
# ...

# %% [markdown]
# Jika kita perhatikan, kolom Total di atas adalah total pertandingan yang diikuti, sekarang kita akan mencari tahu berapa total medali tiap negara
#
#     Total_medal = Total - None

# %%
All_go['Total_medal'] = All_go['Total'] - All_go['None']

# %%
All_go
# Out:
#      NOC  Total  None    G   S   B  Total_medal
# 198  USA    719   455  139  54  71          264
# 68   GBR    478   333   64  55  26          145
# 159  RUS    406   291   52  28  35          115
# 72   GER    536   377   49  43  67          159
# 38   CHN    499   386   46  30  37          113
# 26   BRA    583   533   36   8   6           50
# 10   AUS    518   436   23  34  25           82
# 6    ARG    232   210   21   1   0           22
# 64   FRA    512   416   20  55  21           96
# 97   JPN    436   372   17  13  34           64
# 51   DEN    143   102   15  10  16           41
# 171  SRB    127    73   14  27  13           54
# 102  KOR    263   237   13   3  10           26
# 62   FIJ     53    40   13   0   0           13
# 83   HUN    204   182   12   3   7           22
# 95   JAM     77    47   11  17   2           30
# 135  NED    329   282    9  25  13           47
# 59   ESP    363   318    9  19  17           45
# 93   ITA    399   327    8  40  24           72
# ...

# %% [markdown]
# # Bar Chart

# %% [markdown]
# Kita akan mencoba membuat sebuah bar chart, namun untuk kali ini kita gunakan data yang mudah

# %%
df['Sport'].value_counts()
# Out:
# Athletics                2508
# Swimming                 1568
# Gymnastics                861
# Cycling                   667
# Shooting                  555
# Rowing                    550
# Football                  473
# Canoeing                  441
# Hockey                    390
# Judo                      389
# Sailing                   380
# Equestrianism             355
# Handball                  353
# Fencing                   346
# Wrestling                 346
# Rugby Sevens              299
# Tennis                    286
# Volleyball                283
# Boxing                    283
# Basketball                281
# Water Polo                258
# Weightlifting             255
# Table Tennis              236
# Archery                   200
# Diving                    178
# Badminton                 177
# Taekwondo                 126
# Golf                      120
# Synchronized Swimming     118
# Triathlon                 110
# Beach Volleyball           96
# ...

# %% [markdown]
# kita akan buat bar chart dari data di atas

# %%
plt.figure(figsize=(12,12))
df['Sport'].value_counts().plot(kind='barh', color="r")
plt.title("Total Athlete on Sports in Olympic 2016")
plt.xlabel('Total atlhetes')
plt.ylabel('Sports')
plt.show()

# %% [markdown]
# # Stacked Bar Chart

# %% [markdown]
# kembali ke data awal kita

# %%
All_go
# Out:
#      NOC  Total  None    G   S   B  Total_medal
# 198  USA    719   455  139  54  71          264
# 68   GBR    478   333   64  55  26          145
# 159  RUS    406   291   52  28  35          115
# 72   GER    536   377   49  43  67          159
# 38   CHN    499   386   46  30  37          113
# 26   BRA    583   533   36   8   6           50
# 10   AUS    518   436   23  34  25           82
# 6    ARG    232   210   21   1   0           22
# 64   FRA    512   416   20  55  21           96
# 97   JPN    436   372   17  13  34           64
# 51   DEN    143   102   15  10  16           41
# 171  SRB    127    73   14  27  13           54
# 102  KOR    263   237   13   3  10           26
# 62   FIJ     53    40   13   0   0           13
# 83   HUN    204   182   12   3   7           22
# 95   JAM     77    47   11  17   2           30
# 135  NED    329   282    9  25  13           47
# 59   ESP    363   318    9  19  17           45
# 93   ITA    399   327    8  40  24           72
# ...

# %%
All_go.head(10)
# Out:
#      NOC  Total  None    G   S   B  Total_medal
# 198  USA    719   455  139  54  71          264
# 68   GBR    478   333   64  55  26          145
# 159  RUS    406   291   52  28  35          115
# 72   GER    536   377   49  43  67          159
# 38   CHN    499   386   46  30  37          113
# 26   BRA    583   533   36   8   6           50
# 10   AUS    518   436   23  34  25           82
# 6    ARG    232   210   21   1   0           22
# 64   FRA    512   416   20  55  21           96
# 97   JPN    436   372   17  13  34           64

# %%
all_go_1 = All_go.head(10)

# %%
all_go_1.loc[:,['G','S','B']].plot.bar(stacked=True,color=['gold','silver','brown']) 
# : maksudnya baris tertentu, karena : berarti maksudnya semua baris

# %% [markdown]
# oops x axis nya masih index doang :(
#
# itu karena otomatis yang diset adalah indexnya, maka dari itu kita set dulu indexnya

# %%
all_go_1 = all_go_1.set_index('NOC')

# %%
all_go_1
# Out:
#      Total  None    G   S   B  Total_medal
# NOC
# USA    719   455  139  54  71          264
# GBR    478   333   64  55  26          145
# RUS    406   291   52  28  35          115
# GER    536   377   49  43  67          159
# CHN    499   386   46  30  37          113
# BRA    583   533   36   8   6           50
# AUS    518   436   23  34  25           82
# ARG    232   210   21   1   0           22
# FRA    512   416   20  55  21           96
# JPN    436   372   17  13  34           64

# %%
plt.figure(figsize=(12,12))
all_go_1.loc[:,['G','S','B']].plot.bar(stacked=True,color=['gold','silver','brown']) 
plt.title("perolehan medali tiap negara (top 10)")
plt.ylabel('perolehan medali')
plt.xlabel('negara')
plt.show()

# %% [markdown]
# # Multiple Bar Chart

# %%
plt.figure(figsize=(12,12))
all_go_1.loc[:,['G','S','B']].plot.bar(color=['gold','silver','brown']) 
plt.title("perolehan medali tiap negara (top 10)")
plt.ylabel('perolehan medali')
plt.xlabel('negara')
plt.show()

# %% [markdown]
# # Line Chart

# %% [markdown]
# Line chart bagus digunakan untuk melihat trend. Sekarang kita akan melihat trend perolehan medali dari tahun ke tahun untuk negara tertentu

# %%
df1 = pd.read_csv('athlete_events.csv')
df1
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
df1 = df1.fillna({'Medal' : 'none'})

# %%
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball  none
# 1      Judo Men's Extra-Lightweight  none
# ...

# %%
All_new = pd.DataFrame(df1.groupby(['Year','NOC','Medal'])['Medal'].size())
All_new
# Out:
#                  Medal
# Year NOC Medal
# 1896 AUS Bronze      1
#          Gold        2
#          none        2
#      AUT Bronze      2
#          Gold        2
#          Silver      1
#          none        3
#      DEN Bronze      3
#          Gold        1
#          Silver      2
#          none        9
#      FRA Bronze      2
#          Gold        5
#          Silver      4
#          none       15
#      GBR Bronze      3
#          Gold        3
#          Silver      3
#          none       16
#      GER Bronze      2
#          Gold       25
#          Silver      5
#          none       62
#      GRE Bronze     20
#          Gold       10
#          Silver     18
#          none      100
#      HUN Bronze      3
#          Gold        2
#          Silver      1
# ...                ...
# 2016 TUR Silver      3
#          none      111
#      TUV none        1
#      UAE Bronze      1
#          none       11
#      UGA none       23
#      UKR Bronze      5
# ...

# %%
All_new.columns = ['Total']
All_new.head()
# Out:
#                  Total
# Year NOC Medal
# 1896 AUS Bronze      1
#          Gold        2
#          none        2
#      AUT Bronze      2
#          Gold        2

# %%
All_new = All_new.reset_index()

# %%
All_new.head()
# Out:
#    Year  NOC   Medal  Total
# 0  1896  AUS  Bronze      1
# 1  1896  AUS    Gold      2
# 2  1896  AUS    none      2
# 3  1896  AUT  Bronze      2
# 4  1896  AUT    Gold      2

# %%
All_new['None'] = np.where(All_new['Medal'] == 'none', All_new['Total'], 0)
All_new['G'] = np.where(All_new['Medal'] == 'Gold', All_new['Total'], 0)
All_new['S'] = np.where(All_new['Medal'] == 'Silver', All_new['Total'], 0)
All_new['B'] = np.where(All_new['Medal'] == 'Bronze', All_new['Total'], 0)

All_new = All_new.groupby(['Year','NOC'], as_index = False).sum()

# %%
All_new
# Out:
#       Year  NOC  Total  None    G    S   B
# 0     1896  AUS      5     2    2    0   1
# 1     1896  AUT      8     3    2    1   2
# 2     1896  DEN     15     9    1    2   3
# 3     1896  FRA     26    15    5    4   2
# 4     1896  GBR     25    16    3    3   3
# 5     1896  GER     94    62   25    5   2
# 6     1896  GRE    148   100   10   18  20
# 7     1896  HUN     18    12    2    1   3
# 8     1896  ITA      1     1    0    0   0
# 9     1896  SUI      8     5    1    2   0
# 10    1896  SWE      5     5    0    0   0
# 11    1896  USA     27     7   11    7   2
# 12    1900  ARG      1     1    0    0   0
# 13    1900  AUS      6     0    3    0   3
# 14    1900  AUT     26    20    0    3   3
# 15    1900  BEL    100    57    6   24  13
# 16    1900  BOH      9     6    0    1   2
# 17    1900  BRA      3     3    0    0   0
# 18    1900  CAN      7     5    1    0   1
# 19    1900  COL      1     0    0    1   0
# 20    1900  CUB      2     0    1    1   0
# ...

# %%
All_new['Total_medal'] = All_new['Total'] - All_new['None']

# %%
All_new.head()
# Out:
#    Year  NOC  Total  None  G  S  B  Total_medal
# 0  1896  AUS      5     2  2  0  1            3
# 1  1896  AUT      8     3  2  1  2            5
# 2  1896  DEN     15     9  1  2  3            6
# 3  1896  FRA     26    15  5  4  2           11
# 4  1896  GBR     25    16  3  3  3            9

# %% [markdown]
# kita ambil data GRE (Yunani)

# %%
gre = All_new[All_new['NOC'] == 'GRE']
gre
# Out:
#       Year  NOC  Total  None   G   S   B  Total_medal
# 6     1896  GRE    148   100  10  18  20           48
# 26    1900  GRE      4     4   0   0   0            0
# 50    1904  GRE     17    15   1   0   1            2
# 70    1906  GRE    484   382  24  48  30          102
# 90    1908  GRE     49    45   0   3   1            4
# 112   1912  GRE     77    75   1   0   1            2
# 143   1920  GRE     98    93   0   5   0            5
# 176   1924  GRE     79    78   1   0   0            1
# 221   1928  GRE     47    47   0   0   0            0
# 269   1932  GRE     16    16   0   0   0            0
# 320   1936  GRE     66    66   0   0   0            0
# 367   1948  GRE     99    99   0   0   0            0
# 430   1952  GRE     60    60   0   0   0            0
# 502   1956  GRE     22    21   0   0   1            1
# 576   1960  GRE     59    56   3   0   0            3
# 669   1964  GRE     26    26   0   0   0            0
# ...

# %% [markdown]
# kita gunakan seaborn

# %%
sns.lineplot(x='Year', y='Total_medal', data=gre)

# %% [markdown]
# # Multi Line Chart

# %%
gre
# Out:
#       Year  NOC  Total  None   G   S   B  Total_medal
# 6     1896  GRE    148   100  10  18  20           48
# 26    1900  GRE      4     4   0   0   0            0
# 50    1904  GRE     17    15   1   0   1            2
# 70    1906  GRE    484   382  24  48  30          102
# 90    1908  GRE     49    45   0   3   1            4
# 112   1912  GRE     77    75   1   0   1            2
# 143   1920  GRE     98    93   0   5   0            5
# 176   1924  GRE     79    78   1   0   0            1
# 221   1928  GRE     47    47   0   0   0            0
# 269   1932  GRE     16    16   0   0   0            0
# 320   1936  GRE     66    66   0   0   0            0
# 367   1948  GRE     99    99   0   0   0            0
# 430   1952  GRE     60    60   0   0   0            0
# 502   1956  GRE     22    21   0   0   1            1
# 576   1960  GRE     59    56   3   0   0            3
# 669   1964  GRE     26    26   0   0   0            0
# ...

# %%
gre = gre.sort_values(['Year'])

# %%
plt.figure(figsize=(20,12))
plt.plot(gre['Year'], gre['G'], marker='o', markersize =12, color = 'gold', linewidth = 4, label='gold')
plt.plot(gre['Year'], gre['S'], marker='+', markersize =12, color = 'silver', linewidth = 4, label='silver')
plt.plot(gre['Year'], gre['B'], marker = 'x', markersize =12, color = 'brown', linewidth=4, linestyle='dashed', label='bronze')
plt.legend()
plt.title("trend perolehan medali Yunani")
plt.show()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# Kita akan menggunakan scatter plot untuk melihat hubungan antara tinggi badan dan berat badan para atlet.

# %%
df
# Out:
#             ID                                     Name Sex   Age  Height  \
# 80          22                            Andreea Aanei   F  22.0   170.0
# 139         51                        Nstor Abad Sanjun   M  23.0   167.0
# 140         51                        Nstor Abad Sanjun   M  23.0   167.0
# 141         51                        Nstor Abad Sanjun   M  23.0   167.0
# 142         51                        Nstor Abad Sanjun   M  23.0   167.0
# 143         51                        Nstor Abad Sanjun   M  23.0   167.0
# 144         51                        Nstor Abad Sanjun   M  23.0   167.0
# 148         55                      Antonio Abadia Beci   M  26.0   170.0
# 158         62                        Giovanni Abagnale   M  21.0   198.0
# 161         65                        Patimat Abakarova   F  21.0   165.0
# 175         73                                Luc Abalo   M  31.0   182.0
# 217        105                             Ilyas Abbadi   M  23.0   175.0
# ...

# %%
sns.scatterplot(x='Height',y='Weight', data=df)
plt.show()

# %% [markdown]
# kita dapat lihat bahwa antara tinggi dan berat memiliki kecenderungan positif, maksudnya adalah semakin besar tinggi maka cenderung semakin besar berat badan. Namun data sebanyak itu sebenarnya cukup membingungkan, maka dari itu kita akan menyederhanakannya dengan cara menggunakan rata rata tinggi dan berat dari tiap negara

# %%
avg = df.groupby(['NOC'])['Height','Weight'].mean()

# %%
avg
# Out:
#          Height     Weight
# NOC
# AFG  173.666667  74.000000
# ALB  176.166667  67.166667
# ALG  174.027027  68.378378
# AND  171.500000  66.250000
# ANG  174.500000  73.346154
# ANT  176.750000  71.555556
# ARG  178.659483  75.224138
# ARM  170.323529  73.647059
# ARU  174.285714  68.714286
# ASA  176.750000  75.250000
# AUS  178.576402  73.060547
# AUT  176.894118  70.047059
# AZE  175.666667  72.043478
# BAH  177.121212  68.687500
# BAN  166.500000  71.750000
# BAR  180.692308  75.153846
# BDI  171.800000  59.100000
# BEL  176.224638  67.717391
# BEN  179.333333  78.833333
# BER  174.125000  69.125000
# BHU  164.000000  55.000000
# BIH  180.181818  85.909091
# BIZ  183.666667  79.333333
# BLR  176.556338  71.563380
# BOL  171.333333  64.250000
# BOT  179.400000  67.181818
# BRA  175.418244  71.342513
# BRN  171.321429  61.392857
# BRU  158.000000  57.333333
# BUL  174.637931  70.517241
# ..          ...        ...
# SUR  184.000000  77.500000
# SVK  180.047619  72.793651
# ...

# %%
sns.scatterplot(x='Height',y='Weight', data=avg)
plt.show()

# %% [markdown]
# # Bubble Chart

# %% [markdown]
# Bubble Chart visualisasi yang mirip dengan Scatter Plot hanya saja bisa menampilkan data tambahan dengan menampilkan ukuran-ukuran tertentu.
#
# Pada kasus ini menggunakan All_go (data perolehan mendali setiap negara) dengan sumbu x yaitu Total atlet dan sumbu y yaitu Total Mendali dengan ukuran bersadasarkan Gold.

# %%
All_go.head()
# Out:
#      NOC  Total  None    G   S   B  Total_medal
# 198  USA    719   455  139  54  71          264
# 68   GBR    478   333   64  55  26          145
# 159  RUS    406   291   52  28  35          115
# 72   GER    536   377   49  43  67          159
# 38   CHN    499   386   46  30  37          113

# %%
sns.scatterplot(x='Total', y='Total_medal', size='G', hue='G', data=All_go)
plt.show()

# %% [markdown]
# size digunakan untuk merubah ukuran berdasarkan perolehan gold dan hue digunakan untuk merubah warna

# %% [markdown]
# # Statistical Chart

# %% [markdown]
# ### Box Plot

# %% [markdown]
# Box Plot cocok untuk data yang bertipe numerical dan categorical untuk mengatahui persebaran dan outlier data yang kita gunakan.
#
# Pada kasus ini Box Plot dibuat dari hubungan variabel Sex dan Age, hubungan variabel Sex dan Height, dan hubungan variabel Sex dan Weight.

# %%
df.head()
# Out:
#      ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80   22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 139  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 140  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 141  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 142  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
#
#            Games  Year  Season            City          Sport  \
# 80   2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 139  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 140  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 141  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 142  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight  none
# 139   Gymnastics Men's Individual All-Around  none
# ...

# %%
sns.boxplot(x = 'Sex', y = 'Age', data=df)
plt.title('Persebaran umur berdasarkan jenis kelamin')
plt.show()

# %% [markdown]
# Dari boxplot diatas didapatkan banyak data yang outlier baik dari perempuan maupun laki-laki. Persebaran umur perempuan dan laki-laki hampir sama, hanya saja perempuan terdapat beberapa atlet yang lebih tua dari pada perempuan.

# %%
sns.boxplot(x = 'Sex', y = 'Height', data=df)
plt.title('Persebaran tinggi berdasarkan jenis kelamin')
plt.show()

# %% [markdown]
# Dari boxplot diatas diketahui bahwa kecendrungan data berdasarkan tinggi. Pada boxplot laki-laki persebaran tidak berbeda jauh dari pada perempuan. Tetapi, laki-laki persebaran data sedikit lebih tinggi.

# %%
sns.boxplot(x = 'Sex', y = 'Weight', data=df)
plt.title('Persebaran berat berdasarkan jenis kelamin')
plt.show()

# %% [markdown]
# Didapatkan kecendrungan persebaran data laki-laki sedikit lebih tiggi dari pada perempuan. Outlier pada perempuan ada outlier dibawah nilai minimal sedangkan laki-laki tidak ada.

# %% [markdown]
# ### Histogram

# %% [markdown]
# Histogram visualisasinya hampir sama dengan Bar Chart dari pembahasan sebelumnya. Tetapi, Bar Chart digunakan untuk data yang bertipe categorical sedangkan Histogram untuk data yang bertipe Numerical.
#
# Perbedaan yang lain yaitu pada Bar Chart visualisasi antar batang akan ada spasinya atau jaraknya. Sedangkan, pda Histogram visualisasi antar batang akan berdempetan.

# %%
sns.distplot(df['Age'], kde=False)#kde berhubungan dengan distribusi normal
plt.ylabel('count')
plt.title('distribution of age')
plt.show()

# %% [markdown]
# Dari histogram diatas dapat didapatkan informasi atlet yang paling banyak mengikuti olympiade yaitu dengan umur 20-30 tahun.

# %% [markdown]
# ### Heading

# %% [markdown]
# Heatmap digunakan untuk mengatahui korelasi antar data dengan warna yang menarik. Nah, pada Heatmap ini selain kita bisa melihat besar korelasi dengan menggunakan angka, kita bisa juga melihat korelasi melalui warna. Korelasi nilanya yaitu -1 sampai 1. Ketika nilai mendekati 1 (korelasi positif) dan -1 (korelasi negatif) maka nilai tersebut berkorelasi kuat.

# %%
df.corr()
# Out:
#               ID       Age    Height    Weight  Year
# ID      1.000000 -0.013114 -0.027744 -0.023454   NaN
# Age    -0.013114  1.000000  0.108319  0.141915   NaN
# Height -0.027744  0.108319  1.000000  0.781047   NaN
# Weight -0.023454  0.141915  0.781047  1.000000   NaN
# Year         NaN       NaN       NaN       NaN   NaN

# %% [markdown]
# sebenarnya mencari korelasi akan lebih baik bila datanya berupa angka semua, maka kita akan gunakan All_go

# %%
All_go.corr()
# Out:
#                 Total      None         G         S         B  Total_medal
# Total        1.000000  0.989994  0.770575  0.830648  0.830729     0.881681
# None         0.989994  1.000000  0.685990  0.773144  0.771008     0.806275
# G            0.770575  0.685990  1.000000  0.759143  0.764281     0.936451
# S            0.830648  0.773144  0.759143  1.000000  0.730729     0.896856
# B            0.830729  0.771008  0.764281  0.730729  1.000000     0.904334
# Total_medal  0.881681  0.806275  0.936451  0.896856  0.904334     1.000000

# %% [markdown]
# sekarang kita akan mengubahnya dalam bentuk heatmap

# %%
sns.heatmap(All_go.corr())
plt.show()

# %% [markdown]
# jika kita ingin heatmap tetap menampilkan angka maka lakukan seperti ini

# %%
sns.heatmap(All_go.corr(), annot=True)
plt.show()

# %% [markdown]
# kita bisa merubah warnanya, untuk jenis warnanya dapat dilihat di https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html

# %%
sns.heatmap(All_go.corr(), annot=True, cmap='spring')
plt.show()
