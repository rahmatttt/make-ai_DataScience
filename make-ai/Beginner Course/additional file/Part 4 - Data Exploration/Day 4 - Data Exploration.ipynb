# %% [markdown]
# <img src="img/make ai logo.png" width="180" height="360" align="left"/>

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin-top: 5px">
# <h2> In this lesson, we will learn about data exploration.
#
# We are learning about some basic exploration that used by data scientist.
#
# Let's learn. </h2>
# </div>

# %% [markdown]
# Import package that useful for data scientist.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import data, data is in csv format, and then get first 5 of your data.

# %%
data = pd.read_csv('data/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Get last 5 of your data.

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Get information about your data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# Get only Survived columns.

# %%
data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# Get condition of Survived equals 1

# %%
data[data['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %% [markdown]
# Get shape of data after we take condition above.

# %%
len(data[data['Survived'] == 1])
# Out:
# 342

# %% [markdown]
# Get how many frequency for Sex.

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# Get percentage how many frequency for Sex.

# %%
data['Sex'].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %% [markdown]
# Get statistical value from every column.

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Get full statistical value for every column.

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                  Name   Sex  \
# count    891.000000  891.000000  891.000000                   891   891
# unique          NaN         NaN         NaN                   891     2
# top             NaN         NaN         NaN  Hosono, Mr. Masabumi  male
# freq            NaN         NaN         NaN                     1   577
# mean     446.000000    0.383838    2.308642                   NaN   NaN
# std      257.353842    0.486592    0.836071                   NaN   NaN
# min        1.000000    0.000000    1.000000                   NaN   NaN
# 25%      223.500000    0.000000    2.000000                   NaN   NaN
# 50%      446.000000    0.000000    3.000000                   NaN   NaN
# 75%      668.500000    1.000000    3.000000                   NaN   NaN
# max      891.000000    1.000000    3.000000                   NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare    Cabin  \
# ...

# %% [markdown]
# Get custom precentiles for every column.

# %%
data.describe(percentiles = [.10,.20,.30,.40,.60,.70,.80,.90])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 30%     268.000000    0.000000    2.000000   22.000000    0.000000
# 40%     357.000000    0.000000    2.000000   25.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 60%     535.000000    0.000000    3.000000   31.800000    0.000000
# 70%     624.000000    1.000000    3.000000   36.000000    1.000000
# 80%     713.000000    1.000000    3.000000   41.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# ...

# %% [markdown]
# You can find unique values for each columns.

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# You can take value for each columns too.

# %%
data['Cabin'].values
# Out:
# array([nan, 'C85', nan, 'C123', nan, nan, 'E46', nan, nan, nan, 'G6',
#        'C103', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D56', nan,
#        'A6', nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'B78', nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'D33', nan, 'B30', 'C52', nan, nan, nan,
#        nan, nan, 'B28', 'C83', nan, nan, nan, 'F33', nan, nan, nan, nan,
#        nan, nan, nan, nan, 'F G73', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'E31', nan,
#        nan, nan, 'A5', 'D10 D12', nan, nan, nan, nan, 'D26', nan, nan,
#        nan, nan, nan, nan, nan, 'C110', nan, nan, nan, nan, nan, nan, nan,
#        'B58 B60', nan, nan, nan, nan, 'E101', 'D26', nan, nan, nan,
#        'F E69', nan, nan, nan, nan, nan, nan, nan, 'D47', 'C123', nan,
#        'B86', nan, nan, nan, nan, nan, nan, nan, nan, 'F2', nan, nan,
# ...

# %% [markdown]
# Take condition of **Male** and **PClass** equals 1.

# %%
data[(data['Sex'] == 'male') & (data['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# 30            31         0       1
# 34            35         0       1
# 35            36         0       1
# 54            55         0       1
# 55            56         1       1
# 62            63         0       1
# 64            65         0       1
# 83            84         0       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 124          125         0       1
# 137          138         0       1
# 139          140         0       1
# 155          156         0       1
# 168          169         0       1
# 170          171         0       1
# 174          175         0       1
# 185          186         0       1
# ...

# %% [markdown]
# You can create new columns based on other columns.

# %%
data['Family'] = data['SibSp'] + data['Parch']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       1
# ...

# %% [markdown]
# You can drop columns too.

# %%
data = data.drop('Family', axis=1)
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# You want to know how many **Male** that survived or not.

# %%
data.loc[data['Sex'] == 'male', 'Survived'].value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %% [markdown]
# How many null values on every columns

# %%
pd.isnull(data).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# How to get statistical value from **Age** .

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Null value can be use with inputation or drop data.

# %% [markdown]
# From know I am using median inputation since that there are not much difference with mean.

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# #### Please get some coding so that there are no missing value for Embarked column

# %% [markdown]
# ### New Dataset

# %%
# import data train_mp right now
df = pd.read_csv("data/train_mp.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ###### Description for each columns

# %% [markdown]
# **battery_power** :
# Total energy a battery can store in one time measured in mAh
#
# **blue** :
# Has bluetooth or not
#
# **clock_speed** :
# speed at which microprocessor executes instructions
#
# **dual_sim** :
# Has dual sim support or not
#
# **fc** :
# Front Camera mega pixels
#
# **four_g** :
# Has 4G or not
#
# **int_memory** :
# Internal Memory in Gigabytes
#
# **m_dep** :
# Mobile Depth in cm
#
# **mobile_wt** :
# Weight of mobile phone
#
# **n_cores** :
# Number of cores of processor
#
# **pc** :
# Primary Camera mega pixels
#
# **px_height** :
# Pixel Resolution Height
#
# **px_width** :
# Pixel Resolution Width
#
# **ram** :
# Random Access Memory in Mega Bytes
#
# **sc_h** :
# Screen Height of mobile in cm
#
# **sc_w** :
# Screen Width of mobile in cm
#
# **talk_time** :
# longest time that a single battery charge will last when you are
#
# **three_g** :
# Has 3G or not
#
# **touch_screen** :
# Has touch screen or not
#
# **wifi** :
# Has wifi or not
#
# **price_range** :
# This is the target variable with value of 0(low cost), 1(medium cost), 2(high cost) and 3(very high cost).

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin-top: 20px">
# <h1> Question : </h1>
#
# <b> </b>
# </div>

# %% [markdown]
# #### Part 1

# %% [markdown]
# Find the first quartile of battery_power.

# %% [markdown]
# Find the mode of n_cores.

# %% [markdown]
# Find the mean of ram.

# %% [markdown]
# Find the median of px_width.

# %% [markdown]
# Find the 67th quartile of px_height.

# %% [markdown]
# #### Part 2

# %% [markdown]
# How many mobile phone that doesn't have dual_sim?

# %% [markdown]
# How many mobile phone that have three g, but not four g?

# %% [markdown]
# How many mobile phone that have at least ram 2000?

# %% [markdown]
# If I say that good is when you have at least 5 mp, what is the proportion about good and bad?

# %% [markdown]
# How many in percent that mobile phone doesn't have bluetooth?

# %% [markdown]
# #### Part 3

# %% [markdown]
# After you're getting some exploration, do you can get some insight? Please tell me minimum 3 insight.
