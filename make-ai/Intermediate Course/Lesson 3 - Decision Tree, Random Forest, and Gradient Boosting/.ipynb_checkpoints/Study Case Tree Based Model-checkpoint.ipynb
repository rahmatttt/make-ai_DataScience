# %% [markdown]
# # Study Case Tree Based Model

# %% [markdown]
# ## Import Packages and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import math
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from mlxtend.plotting import plot_decision_regions

import warnings
warnings.filterwarnings('ignore')

# %%
data_mp = pd.read_csv('train_mp.csv')
data_mp.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# ## Simple Analyze Data

# %%
data_mp['price_range'].value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %%
data_mp.shape
# Out:
# (2000, 21)

# %%
data_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    2000 non-null int64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null int64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null int64
# price_range      2000 non-null int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
data_mp.corr()['price_range']
# Out:
# battery_power    0.200723
# blue             0.020573
# clock_speed     -0.006606
# dual_sim         0.017444
# fc               0.021998
# four_g           0.014772
# int_memory       0.044435
# m_dep            0.000853
# mobile_wt       -0.030302
# n_cores          0.004399
# pc               0.033599
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# sc_h             0.022986
# sc_w             0.038711
# talk_time        0.021859
# three_g          0.023611
# touch_screen    -0.030411
# wifi             0.018785
# price_range      1.000000
# Name: price_range, dtype: float64

# %% [markdown]
# ## Choosing Features
#
# Kita akan mencoba menggunakan semua fitur yang ada

# %%
X = data_mp.drop(['price_range'], axis = 1)
y = data_mp['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=45)

# %%
y_train.value_counts()
# Out:
# 3    423
# 0    396
# 2    395
# 1    386
# Name: price_range, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    114
# 2    105
# 0    104
# 3     77
# Name: price_range, dtype: int64

# %% [markdown]
# ## Create Model and Training

# %%
model_de = DecisionTreeClassifier(criterion='entropy')
model_dg = DecisionTreeClassifier(criterion='gini')
model_rfe = RandomForestClassifier(criterion='entropy')
model_rfg = RandomForestClassifier(criterion='gini')
model_gb = GradientBoostingClassifier()

# %%
model_de.fit(X_train,y_train)
model_dg.fit(X_train,y_train)
model_rfe.fit(X_train,y_train)
model_rfg.fit(X_train,y_train)
model_gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ## Testing

# %%
predict_de = model_de.predict(X_test)
predict_dg = model_dg.predict(X_test)
predict_rfe = model_rfe.predict(X_test)
predict_rfg = model_rfg.predict(X_test)
predict_gb = model_gb.predict(X_test)

# %%
pd.DataFrame({
    'Actual' : y_test,
    'Decision Tree (entropy)' : predict_de,
    'Decision Tree (gini index)' : predict_dg,
    'Random Forest (entropy)' : predict_rfe,
    'Random Forest (gini index)' : predict_rfg,
    'Gradient Boost' : predict_gb
})
# Out:
#       Actual  Decision Tree (entropy)  Decision Tree (gini index)  \
# 452        3                        3                           3
# 212        0                        0                           0
# 39         2                        1                           2
# 9          0                        0                           0
# 448        2                        2                           3
# 14         0                        0                           0
# 403        2                        2                           1
# 935        3                        2                           3
# 1389       0                        0                           0
# 604        1                        1                           1
# 1885       0                        0                           0
# 246        0                        0                           0
# 1888       0                        0                           0
# ...

# %% [markdown]
# ## Evaluation

# %%
print("Akurasi Decision Tree (entropy) : ", model_de.score(X_test, y_test)*100,"%")
print("Akurasi Decision Tree (gini index) : ", model_dg.score(X_test, y_test)*100,"%")
print("Akurasi Random Forest (entropy) : ", model_rfe.score(X_test, y_test)*100,"%")
print("Akurasi Random Forest (gini index) : ", model_rfg.score(X_test, y_test)*100,"%")
print("Akurasi Gradien Boosting : ", model_gb.score(X_test, y_test)*100,"%")
# Out:
# Akurasi Decision Tree (entropy) :  84.75 %
# Akurasi Decision Tree (gini index) :  83.25 %
# Akurasi Random Forest (entropy) :  80.0 %
# Akurasi Random Forest (gini index) :  85.75 %
# Akurasi Gradien Boosting :  91.25 %

# %% [markdown]
# Hasil terbaik didapatkan dengan menggunakan metode gradien boosting

# %% [markdown]
# ## Visualization

# %%
from sklearn import tree
from sklearn.tree import export_graphviz
from IPython.display import SVG, display
from graphviz import Source

# %%
labels = X.columns

# %% [markdown]
# ### Decision Tree (entropy)

# %%
graph = Source(tree.export_graphviz(model_de,
out_file = None, feature_names = labels 
                , class_names = ['0', '1', '2', '3']
                , filled = True))

display(SVG(graph.pipe(format='svg')))

# %% [markdown]
# ### Decision Tree (gini index)

# %%
graph = Source(tree.export_graphviz(model_dg,
out_file = None, feature_names = labels 
                , class_names = ['0', '1', '2', '3']
                , filled = True))

display(SVG(graph.pipe(format='svg')))

# %% [markdown]
# ## Interactive Visualization

# %%
from ipywidgets import interactive

# %%
# class labels
labels = X.columns
def plot_tree(crit, split, depth, min_split, min_leaf=0.2):

    estimator = DecisionTreeClassifier(random_state = 45
    , criterion = crit
    , splitter = split
    , max_depth = depth
    , min_samples_split=min_split
    , min_samples_leaf=min_leaf)
    estimator.fit(X_train, y_train)

    graph = Source(tree.export_graphviz(estimator
    , out_file=None
    , feature_names=labels
    , class_names=['0','1','2','3']
    , filled = True))

    display(SVG(graph.pipe(format='svg')))

    return estimator

inter=interactive(plot_tree
, crit = ["gini","entropy"]
, split = ["best","random"]
, depth=[1,2,3,4]
, min_split=(1,100)
, min_leaf=(1,50))

display(inter)
# Out:
# interactive(children=(Dropdown(description='crit', options=('gini', 'entropy'), value='gini'), Dropdown(descri…
